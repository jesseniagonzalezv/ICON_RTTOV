# %% [markdown]
# # 2D

# %% [markdown]
# #### cloud day

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_cloud_day_DOM01_ML_20130502T180000Z.nc
# Out:
# netcdf \2d_cloud_day_DOM01_ML_20130502T180000Z {
# dimensions:
# 	ncells = 2323968 ;
# 	vertices = 3 ;
# 	lev = 1 ;
# 	bnds = 2 ;
# 	lev_2 = 1 ;
# 	lev_3 = 1 ;
# 	time = UNLIMITED ; // (60 currently)
# variables:
# 	double lev(lev) ;
# 		lev:standard_name = "air_pressure" ;
# 		lev:long_name = "pressure" ;
# 		lev:units = "hPa" ;
# 		lev:positive = "up" ;
# 		lev:axis = "Z" ;
# 		lev:bounds = "lev_bnds" ;
# 	double lev_bnds(lev, bnds) ;
# 	double lev_2(lev_2) ;
# 		lev_2:standard_name = "air_pressure" ;
# 		lev_2:long_name = "pressure" ;
# 		lev_2:units = "hPa" ;
# 		lev_2:positive = "up" ;
# 		lev_2:axis = "Z" ;
# 		lev_2:bounds = "lev_2_bnds" ;
# 	double lev_2_bnds(lev_2, bnds) ;
# 	double lev_3(lev_3) ;
# 		lev_3:standard_name = "air_pressure" ;
# 		lev_3:long_name = "pressure" ;
# 		lev_3:units = "hPa" ;
# 		lev_3:positive = "up" ;
# 		lev_3:axis = "Z" ;
# 		lev_3:bounds = "lev_3_bnds" ;
# 	double lev_3_bnds(lev_3, bnds) ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# ...

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_cloud_day_DOM02_ML_20130502T180000Z.nc
# Out:
# netcdf \2d_cloud_day_DOM02_ML_20130502T180000Z {
# dimensions:
# 	ncells = 7616120 ;
# 	vertices = 3 ;
# 	lev = 1 ;
# 	bnds = 2 ;
# 	lev_2 = 1 ;
# 	lev_3 = 1 ;
# 	time = UNLIMITED ; // (60 currently)
# variables:
# 	double lev(lev) ;
# 		lev:standard_name = "air_pressure" ;
# 		lev:long_name = "pressure" ;
# 		lev:units = "hPa" ;
# 		lev:positive = "up" ;
# 		lev:axis = "Z" ;
# 		lev:bounds = "lev_bnds" ;
# 	double lev_bnds(lev, bnds) ;
# 	double lev_2(lev_2) ;
# 		lev_2:standard_name = "air_pressure" ;
# 		lev_2:long_name = "pressure" ;
# 		lev_2:units = "hPa" ;
# 		lev_2:positive = "up" ;
# 		lev_2:axis = "Z" ;
# 		lev_2:bounds = "lev_2_bnds" ;
# 	double lev_2_bnds(lev_2, bnds) ;
# 	double lev_3(lev_3) ;
# 		lev_3:standard_name = "air_pressure" ;
# 		lev_3:long_name = "pressure" ;
# 		lev_3:units = "hPa" ;
# 		lev_3:positive = "up" ;
# 		lev_3:axis = "Z" ;
# 		lev_3:bounds = "lev_3_bnds" ;
# 	double lev_3_bnds(lev_3, bnds) ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# ...

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_cloud_day_DOM03_ML_20130502T180000Z.nc
# Out:
# netcdf \2d_cloud_day_DOM03_ML_20130502T180000Z {
# dimensions:
# 	ncells = 22282304 ;
# 	vertices = 3 ;
# 	lev = 1 ;
# 	bnds = 2 ;
# 	lev_2 = 1 ;
# 	lev_3 = 1 ;
# 	time = UNLIMITED ; // (60 currently)
# variables:
# 	double lev(lev) ;
# 		lev:standard_name = "air_pressure" ;
# 		lev:long_name = "pressure" ;
# 		lev:units = "hPa" ;
# 		lev:positive = "up" ;
# 		lev:axis = "Z" ;
# 		lev:bounds = "lev_bnds" ;
# 	double lev_bnds(lev, bnds) ;
# 	double lev_2(lev_2) ;
# 		lev_2:standard_name = "air_pressure" ;
# 		lev_2:long_name = "pressure" ;
# 		lev_2:units = "hPa" ;
# 		lev_2:positive = "up" ;
# 		lev_2:axis = "Z" ;
# 		lev_2:bounds = "lev_2_bnds" ;
# 	double lev_2_bnds(lev_2, bnds) ;
# 	double lev_3(lev_3) ;
# 		lev_3:standard_name = "air_pressure" ;
# 		lev_3:long_name = "pressure" ;
# 		lev_3:units = "hPa" ;
# 		lev_3:positive = "up" ;
# 		lev_3:axis = "Z" ;
# 		lev_3:bounds = "lev_3_bnds" ;
# 	double lev_3_bnds(lev_3, bnds) ;
# 	double time(time) ;
# ...

# %% [markdown]
# ### rad new day

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_rad_new_day_DOM01_ML_20130502T180000Z.nc
# Out:
# netcdf \2d_rad_new_day_DOM01_ML_20130502T180000Z {
# dimensions:
# 	time = UNLIMITED ; // (60 currently)
# 	ncells = 2323968 ;
# variables:
# 	float sob_t(time, ncells) ;
# 		sob_t:standard_name = "sob_t" ;
# 		sob_t:long_name = "shortwave net flux at TOA" ;
# 		sob_t:units = "W m-2" ;
# 		sob_t:param = "9.4.0" ;
# 		sob_t:grid_type = "unstructured" ;
# 		sob_t:number_of_grid_in_reference = 1 ;
# 		sob_t:level_type = "toa" ;
# 	float sod_t(time, ncells) ;
# 		sod_t:standard_name = "sod_t" ;
# 		sod_t:long_name = "downward shortwave flux at TOA" ;
# 		sod_t:units = "W m-2" ;
# 		sod_t:param = "7.4.0" ;
# 		sod_t:grid_type = "unstructured" ;
# 		sod_t:number_of_grid_in_reference = 1 ;
# 		sod_t:level_type = "toa" ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "day as %Y%m%d.%f" ;
# 		time:calendar = "proleptic_gregorian" ;
# 		time:axis = "T" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.7.2 (http://mpimet.mpg.de/cdi)" ;
# ...

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_rad_new_day_DOM02_ML_20130502T180000Z.nc
# Out:
# netcdf \2d_rad_new_day_DOM02_ML_20130502T180000Z {
# dimensions:
# 	time = UNLIMITED ; // (60 currently)
# 	ncells = 7616120 ;
# variables:
# 	float sob_t(time, ncells) ;
# 		sob_t:standard_name = "sob_t" ;
# 		sob_t:long_name = "shortwave net flux at TOA" ;
# 		sob_t:units = "W m-2" ;
# 		sob_t:param = "9.4.0" ;
# 		sob_t:grid_type = "unstructured" ;
# 		sob_t:number_of_grid_in_reference = 1 ;
# 		sob_t:level_type = "toa" ;
# 	float sod_t(time, ncells) ;
# 		sod_t:standard_name = "sod_t" ;
# 		sod_t:long_name = "downward shortwave flux at TOA" ;
# 		sod_t:units = "W m-2" ;
# 		sod_t:param = "7.4.0" ;
# 		sod_t:grid_type = "unstructured" ;
# 		sod_t:number_of_grid_in_reference = 1 ;
# 		sod_t:level_type = "toa" ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "day as %Y%m%d.%f" ;
# 		time:calendar = "proleptic_gregorian" ;
# 		time:axis = "T" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.7.2 (http://mpimet.mpg.de/cdi)" ;
# ...

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_rad_new_day_DOM03_ML_20130502T180000Z.nc
# Out:
# netcdf \2d_rad_new_day_DOM03_ML_20130502T180000Z {
# dimensions:
# 	time = UNLIMITED ; // (60 currently)
# 	ncells = 22282304 ;
# variables:
# 	float sob_t(time, ncells) ;
# 		sob_t:standard_name = "sob_t" ;
# 		sob_t:long_name = "shortwave net flux at TOA" ;
# 		sob_t:units = "W m-2" ;
# 		sob_t:param = "9.4.0" ;
# 		sob_t:grid_type = "unstructured" ;
# 		sob_t:number_of_grid_in_reference = 1 ;
# 		sob_t:level_type = "toa" ;
# 	float sod_t(time, ncells) ;
# 		sod_t:standard_name = "sod_t" ;
# 		sod_t:long_name = "downward shortwave flux at TOA" ;
# 		sod_t:units = "W m-2" ;
# 		sod_t:param = "7.4.0" ;
# 		sod_t:grid_type = "unstructured" ;
# 		sod_t:number_of_grid_in_reference = 1 ;
# 		sod_t:level_type = "toa" ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "day as %Y%m%d.%f" ;
# 		time:calendar = "proleptic_gregorian" ;
# 		time:axis = "T" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.7.2 (http://mpimet.mpg.de/cdi)" ;
# ...

# %% [markdown]
# #### surface day

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_surface_day_DOM01_ML_20130502T180000Z.nc
# Out:
# netcdf \2d_surface_day_DOM01_ML_20130502T180000Z {
# dimensions:
# 	height = 1 ;
# 	time = UNLIMITED ; // (60 currently)
# 	ncells = 2323968 ;
# variables:
# 	double height(height) ;
# 		height:standard_name = "height" ;
# 		height:long_name = "height" ;
# 		height:units = "m" ;
# 		height:positive = "up" ;
# 		height:axis = "Z" ;
# 	float lhfl_s(time, ncells) ;
# 		lhfl_s:standard_name = "lhfl_s" ;
# 		lhfl_s:long_name = "surface latent heat flux" ;
# 		lhfl_s:units = "W m-2" ;
# 		lhfl_s:param = "10.0.0" ;
# 		lhfl_s:grid_type = "unstructured" ;
# 		lhfl_s:number_of_grid_in_reference = 1 ;
# 	float ps(time, ncells) ;
# 		ps:standard_name = "surface_air_pressure" ;
# 		ps:long_name = "surface pressure" ;
# 		ps:units = "Pa" ;
# 		ps:param = "0.3.0" ;
# 		ps:grid_type = "unstructured" ;
# 		ps:number_of_grid_in_reference = 1 ;
# 	float shfl_s(time, ncells) ;
# 		shfl_s:standard_name = "shfl_s" ;
# 		shfl_s:long_name = "surface sensible heat flux" ;
# 		shfl_s:units = "W m-2" ;
# ...

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_surface_day_DOM02_ML_20130502T180000Z.nc
# Out:
# netcdf \2d_surface_day_DOM02_ML_20130502T180000Z {
# dimensions:
# 	height = 1 ;
# 	time = UNLIMITED ; // (60 currently)
# 	ncells = 7616120 ;
# variables:
# 	double height(height) ;
# 		height:standard_name = "height" ;
# 		height:long_name = "height" ;
# 		height:units = "m" ;
# 		height:positive = "up" ;
# 		height:axis = "Z" ;
# 	float lhfl_s(time, ncells) ;
# 		lhfl_s:standard_name = "lhfl_s" ;
# 		lhfl_s:long_name = "surface latent heat flux" ;
# 		lhfl_s:units = "W m-2" ;
# 		lhfl_s:param = "10.0.0" ;
# 		lhfl_s:grid_type = "unstructured" ;
# 		lhfl_s:number_of_grid_in_reference = 1 ;
# 	float ps(time, ncells) ;
# 		ps:standard_name = "surface_air_pressure" ;
# 		ps:long_name = "surface pressure" ;
# 		ps:units = "Pa" ;
# 		ps:param = "0.3.0" ;
# 		ps:grid_type = "unstructured" ;
# 		ps:number_of_grid_in_reference = 1 ;
# 	float shfl_s(time, ncells) ;
# 		shfl_s:standard_name = "shfl_s" ;
# 		shfl_s:long_name = "surface sensible heat flux" ;
# 		shfl_s:units = "W m-2" ;
# ...

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_surface_day_DOM03_ML_20130502T180000Z.nc
# Out:
# netcdf \2d_surface_day_DOM03_ML_20130502T180000Z {
# dimensions:
# 	height = 1 ;
# 	time = UNLIMITED ; // (60 currently)
# 	ncells = 22282304 ;
# variables:
# 	double height(height) ;
# 		height:standard_name = "height" ;
# 		height:long_name = "height" ;
# 		height:units = "m" ;
# 		height:positive = "up" ;
# 		height:axis = "Z" ;
# 	float lhfl_s(time, ncells) ;
# 		lhfl_s:standard_name = "lhfl_s" ;
# 		lhfl_s:long_name = "surface latent heat flux" ;
# 		lhfl_s:units = "W m-2" ;
# 		lhfl_s:param = "10.0.0" ;
# 		lhfl_s:grid_type = "unstructured" ;
# 		lhfl_s:number_of_grid_in_reference = 1 ;
# 	float ps(time, ncells) ;
# 		ps:standard_name = "surface_air_pressure" ;
# 		ps:long_name = "surface pressure" ;
# 		ps:units = "Pa" ;
# 		ps:param = "0.3.0" ;
# 		ps:grid_type = "unstructured" ;
# 		ps:number_of_grid_in_reference = 1 ;
# 	float shfl_s(time, ncells) ;
# 		shfl_s:standard_name = "shfl_s" ;
# 		shfl_s:long_name = "surface sensible heat flux" ;
# 		shfl_s:units = "W m-2" ;
# ...

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_cloud_day_lonlat_20130424T120000Z.nc
# Out:
# netcdf \2d_cloud_day_lonlat_20130424T120000Z {
# dimensions:
# 	lon = 588 ;
# 	lat = 516 ;
# 	height_2 = 151 ;
# 	bnds = 2 ;
# 	time = UNLIMITED ; // (1 currently)
# variables:
# 	double lon(lon) ;
# 		lon:standard_name = "longitude" ;
# 		lon:long_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 		lon:axis = "X" ;
# 	double lat(lat) ;
# 		lat:standard_name = "latitude" ;
# 		lat:long_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 		lat:axis = "Y" ;
# 	double height_2(height_2) ;
# 		height_2:long_name = "generalized height" ;
# 		height_2:axis = "Z" ;
# 		height_2:bounds = "height_2_bnds" ;
# 	double height_2_bnds(height_2, bnds) ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "day as %Y%m%d.%f" ;
# 		time:calendar = "proleptic_gregorian" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.6.9 (http://mpimet.mpg.de/cdi)" ;
# 		:Conventions = "CF-1.4" ;
# ...

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_cloud_day_triang_20130424T120000Z.nc
# Out:
# HDF5-DIAG: Error detected in HDF5 (1.10.4) thread 140085841536832:
#   #000: H5F.c line 509 in H5Fopen(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: H5Fint.c line 1400 in H5F__open(): unable to open file
#     major: File accessibilty
#     minor: Unable to open file
#   #002: H5Fint.c line 1700 in H5F_open(): unable to read superblock
#     major: File accessibilty
#     minor: Read failed
#   #003: H5Fsuper.c line 623 in H5F__super_read(): truncated file: eof = 104857600, sblock->base_addr = 0, stored_eof = 1965084559
#     major: File accessibilty
#     minor: File has been truncated
# ncdump: /poorgafile1/climate/hdcp2/2013/2d_cloud_day_triang_20130424T120000Z.nc: /poorgafile1/climate/hdcp2/2013/2d_cloud_day_triang_20130424T120000Z.nc: NetCDF: HDF error

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_rad_new_day_DOM01.nc
# Out:
# netcdf \2d_rad_new_day_DOM01 {
# dimensions:
# 	time = UNLIMITED ; // (847 currently)
# 	ncells = 2323968 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "day as %Y%m%d.%f" ;
# 		time:calendar = "proleptic_gregorian" ;
# 		time:axis = "T" ;
# 	float sob_t(time, ncells) ;
# 		sob_t:standard_name = "sob_t" ;
# 		sob_t:long_name = "shortwave net flux at TOA" ;
# 		sob_t:units = "W m-2" ;
# 		sob_t:param = "9.4.0" ;
# 		sob_t:grid_type = "unstructured" ;
# 		sob_t:number_of_grid_in_reference = 1 ;
# 		sob_t:level_type = "toa" ;
# 	float sod_t(time, ncells) ;
# 		sod_t:standard_name = "sod_t" ;
# 		sod_t:long_name = "downward shortwave flux at TOA" ;
# 		sod_t:units = "W m-2" ;
# 		sod_t:param = "7.4.0" ;
# 		sod_t:grid_type = "unstructured" ;
# 		sod_t:number_of_grid_in_reference = 1 ;
# 		sod_t:level_type = "toa" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.7.2 (http://mpimet.mpg.de/cdi)" ;
# ...

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_rad_new_day_DOM02.nc
# Out:
# netcdf \2d_rad_new_day_DOM02 {
# dimensions:
# 	time = UNLIMITED ; // (847 currently)
# 	ncells = 7616120 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "day as %Y%m%d.%f" ;
# 		time:calendar = "proleptic_gregorian" ;
# 		time:axis = "T" ;
# 	float sob_t(time, ncells) ;
# 		sob_t:standard_name = "sob_t" ;
# 		sob_t:long_name = "shortwave net flux at TOA" ;
# 		sob_t:units = "W m-2" ;
# 		sob_t:param = "9.4.0" ;
# 		sob_t:grid_type = "unstructured" ;
# 		sob_t:number_of_grid_in_reference = 1 ;
# 		sob_t:level_type = "toa" ;
# 	float sod_t(time, ncells) ;
# 		sod_t:standard_name = "sod_t" ;
# 		sod_t:long_name = "downward shortwave flux at TOA" ;
# 		sod_t:units = "W m-2" ;
# 		sod_t:param = "7.4.0" ;
# 		sod_t:grid_type = "unstructured" ;
# 		sod_t:number_of_grid_in_reference = 1 ;
# 		sod_t:level_type = "toa" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.7.2 (http://mpimet.mpg.de/cdi)" ;
# ...

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_rad_new_day_DOM03.nc
# Out:
# netcdf \2d_rad_new_day_DOM03 {
# dimensions:
# 	time = UNLIMITED ; // (847 currently)
# 	ncells = 22282304 ;
# variables:
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "day as %Y%m%d.%f" ;
# 		time:calendar = "proleptic_gregorian" ;
# 		time:axis = "T" ;
# 	float sob_t(time, ncells) ;
# 		sob_t:standard_name = "sob_t" ;
# 		sob_t:long_name = "shortwave net flux at TOA" ;
# 		sob_t:units = "W m-2" ;
# 		sob_t:param = "9.4.0" ;
# 		sob_t:grid_type = "unstructured" ;
# 		sob_t:number_of_grid_in_reference = 1 ;
# 		sob_t:level_type = "toa" ;
# 	float sod_t(time, ncells) ;
# 		sod_t:standard_name = "sod_t" ;
# 		sod_t:long_name = "downward shortwave flux at TOA" ;
# 		sod_t:units = "W m-2" ;
# 		sod_t:param = "7.4.0" ;
# 		sod_t:grid_type = "unstructured" ;
# 		sod_t:number_of_grid_in_reference = 1 ;
# 		sod_t:level_type = "toa" ;
#
# // global attributes:
# 		:CDI = "Climate Data Interface version 1.7.2 (http://mpimet.mpg.de/cdi)" ;
# ...

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_surface_day_DOM01.nc
# Out:
# netcdf \2d_surface_day_DOM01 {
# dimensions:
# 	height = 1 ;
# 	time = UNLIMITED ; // (847 currently)
# 	ncells = 2323968 ;
# variables:
# 	double height(height) ;
# 		height:standard_name = "height" ;
# 		height:long_name = "height" ;
# 		height:units = "m" ;
# 		height:positive = "up" ;
# 		height:axis = "Z" ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "day as %Y%m%d.%f" ;
# 		time:calendar = "proleptic_gregorian" ;
# 		time:axis = "T" ;
# 	float lhfl_s(time, ncells) ;
# 		lhfl_s:standard_name = "lhfl_s" ;
# 		lhfl_s:long_name = "surface latent heat flux" ;
# 		lhfl_s:units = "W m-2" ;
# 		lhfl_s:param = "10.0.0" ;
# 		lhfl_s:grid_type = "unstructured" ;
# 		lhfl_s:number_of_grid_in_reference = 1 ;
# 	float shfl_s(time, ncells) ;
# 		shfl_s:standard_name = "shfl_s" ;
# 		shfl_s:long_name = "surface sensible heat flux" ;
# 		shfl_s:units = "W m-2" ;
# 		shfl_s:param = "11.0.0" ;
# 		shfl_s:grid_type = "unstructured" ;
# ...

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_surface_day_DOM02.nc
# Out:
# netcdf \2d_surface_day_DOM02 {
# dimensions:
# 	height = 1 ;
# 	time = UNLIMITED ; // (847 currently)
# 	ncells = 7616120 ;
# variables:
# 	double height(height) ;
# 		height:standard_name = "height" ;
# 		height:long_name = "height" ;
# 		height:units = "m" ;
# 		height:positive = "up" ;
# 		height:axis = "Z" ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "day as %Y%m%d.%f" ;
# 		time:calendar = "proleptic_gregorian" ;
# 		time:axis = "T" ;
# 	float lhfl_s(time, ncells) ;
# 		lhfl_s:standard_name = "lhfl_s" ;
# 		lhfl_s:long_name = "surface latent heat flux" ;
# 		lhfl_s:units = "W m-2" ;
# 		lhfl_s:param = "10.0.0" ;
# 		lhfl_s:grid_type = "unstructured" ;
# 		lhfl_s:number_of_grid_in_reference = 1 ;
# 	float shfl_s(time, ncells) ;
# 		shfl_s:standard_name = "shfl_s" ;
# 		shfl_s:long_name = "surface sensible heat flux" ;
# 		shfl_s:units = "W m-2" ;
# 		shfl_s:param = "11.0.0" ;
# 		shfl_s:grid_type = "unstructured" ;
# ...

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/2013/2d_surface_day_DOM03.nc
# Out:
# netcdf \2d_surface_day_DOM03 {
# dimensions:
# 	height = 1 ;
# 	time = UNLIMITED ; // (847 currently)
# 	ncells = 22282304 ;
# variables:
# 	double height(height) ;
# 		height:standard_name = "height" ;
# 		height:long_name = "height" ;
# 		height:units = "m" ;
# 		height:positive = "up" ;
# 		height:axis = "Z" ;
# 	double time(time) ;
# 		time:standard_name = "time" ;
# 		time:units = "day as %Y%m%d.%f" ;
# 		time:calendar = "proleptic_gregorian" ;
# 		time:axis = "T" ;
# 	float lhfl_s(time, ncells) ;
# 		lhfl_s:standard_name = "lhfl_s" ;
# 		lhfl_s:long_name = "surface latent heat flux" ;
# 		lhfl_s:units = "W m-2" ;
# 		lhfl_s:param = "10.0.0" ;
# 		lhfl_s:grid_type = "unstructured" ;
# 		lhfl_s:number_of_grid_in_reference = 1 ;
# 	float shfl_s(time, ncells) ;
# 		shfl_s:standard_name = "shfl_s" ;
# 		shfl_s:long_name = "surface sensible heat flux" ;
# 		shfl_s:units = "W m-2" ;
# 		shfl_s:param = "11.0.0" ;
# 		shfl_s:grid_type = "unstructured" ;
# ...

# %%
#!/bin/ksh
scp m214061@mistral.dkrz.de://work/bb0777/m214061/2d_cloud_day_DOM03_ML_20130502T150000Z.nc .&
scp m214061@mistral.dkrz.de://work/bb0777/m214061/3d_coarse_day_ll_DOM03_ML_20130502T110000Z.nc .&
