# %% [markdown]
# # MODIS

# %%
# !ncdump -h /poorgafile1/climate/hdcp2/modis/MOD06_L2.A2013110.0925.006.2015067143636.hdf
# Out:
# netcdf MOD06_L2.A2013110.0925.006.2015067143636 {
# dimensions:
# 	Cell_Along_Swath_5km\:mod06 = 406 ;
# 	Cell_Across_Swath_5km\:mod06 = 270 ;
# 	Band_Number\:mod06 = 7 ;
# 	Band_Forcing\:mod06 = 5 ;
# 	Band_Ratio\:mod06 = 5 ;
# 	Cell_Along_Swath_1km\:mod06 = 2030 ;
# 	Cell_Across_Swath_1km\:mod06 = 1354 ;
# 	Cloud_Mask_5km_Num_Bytes\:mod06 = 2 ;
# 	QA_Parameter_5km\:mod06 = 10 ;
# 	Cloud_Mask_1km_Num_Bytes\:mod06 = 2 ;
# 	RadTran_NRE_Ice\:mod06 = 12 ;
# 	RadTran_NWL\:mod06 = 7 ;
# 	RadTran_NRE_Liq\:mod06 = 18 ;
# 	SPI_nband\:mod06 = 2 ;
# 	RFM_nband\:mod06 = 3 ;
# 	ACR_nband\:mod06 = 6 ;
# 	QA_Parameter_1km\:mod06 = 9 ;
# 	fakeDim17 = 17 ;
# variables:
# 	float Latitude(Cell_Along_Swath_5km\:mod06, Cell_Across_Swath_5km\:mod06) ;
# 		Latitude:valid_range = -90.f, 90.f ;
# 		Latitude:_FillValue = -999.9f ;
# 		Latitude:long_name = "Geodetic Latitude" ;
# 		Latitude:units = "degrees_north" ;
# 		Latitude:scale_factor = 1. ;
# 		Latitude:add_offset = 0. ;
# ...
